# %%
import pandas
pandas.__version__
# Out:
# '1.5.3'

# %%
import numpy as np
import pandas as pd

# %%
x=pd.Series([1,2,3,4])
x
# Out:
# 0    1
# 1    2
# 2    3
# 3    4
# dtype: int64

# %%
x.values
# Out:
# array([1, 2, 3, 4])

# %%
x.index
# Out:
# RangeIndex(start=0, stop=4, step=1)

# %%
x=pd.Series([1,2,3,4], index=['a', 'b', 'c', 'd'])
x
# Out:
# a    1
# b    2
# c    3
# d    4
# dtype: int64

# %%
x['c']
# Out:
# 3

# %%
x[3]
# Out:
# 4

# %%
x.name=5
x.index.name='e'
x
# Out:
# e
# a    1
# b    2
# c    3
# d    4
# Name: 5, dtype: int64

# %%
np.log(x)
# Out:
# e
# a    0.000000
# b    0.693147
# c    1.098612
# d    1.386294
# Name: 5, dtype: float64

# %%
x[x>2]
# Out:
# e
# c    3
# d    4
# Name: 5, dtype: int64

# %%
x_dict={'a':1, 'b':2, 'c':3, 'd':4}
print(x_dict)
pd.Series(x_dict)
# Out:
# {'a': 1, 'b': 2, 'c': 3, 'd': 4}
# a    1
# b    2
# c    3
# d    4
# dtype: int64

# %%
x={'name':['a', 'b', 'c', 'd'], 'surname':['e', 'f', 'g', 'h'], 'age':[1,2,3,4]}
print(x)
x=pd.DataFrame(x)
x
# Out:
# {'name': ['a', 'b', 'c', 'd'], 'surname': ['e', 'f', 'g', 'h'], 'age': [1, 2, 3, 4]}
#   name surname  age
# 0    a       e    1
# 1    b       f    2
# 2    c       g    3
# 3    d       h    4

# %%
y=pd.DataFrame(x, columns=["age", "name","surname"])
y
# Out:
#    age name surname
# 0    1    a       e
# 1    2    b       f
# 2    3    c       g
# 3    4    d       h

# %%
y['middle name']=y.age/y.age
y
# Out:
#    age name surname  middle name
# 0    1    a       e          1.0
# 1    2    b       f          1.0
# 2    3    c       g          1.0
# 3    4    d       h          1.0

# %%
y['d0b']=pd.Series(range(4), index=[1,2,3,4])
y
# Out:
#    age name surname  middle name  d0b
# 0    1    a       e          1.0  NaN
# 1    2    b       f          1.0  0.0
# 2    3    c       g          1.0  1.0
# 3    4    d       h          1.0  2.0

# %%
y.to_dict()
# Out:
# {'age': {0: 1, 1: 2, 2: 3, 3: 4},
#  'name': {0: 'a', 1: 'b', 2: 'c', 3: 'd'},
#  'surname': {0: 'e', 1: 'f', 2: 'g', 3: 'h'},
#  'middle name': {0: 1.0, 1: 1.0, 2: 1.0, 3: 1.0},
#  'd0b': {0: nan, 1: 0.0, 2: 1.0, 3: 2.0}}

# %%
pd.DataFrame(y.to_dict())
# Out:
#    age name surname  middle name  d0b
# 0    1    a       e          1.0  NaN
# 1    2    b       f          1.0  0.0
# 2    3    c       g          1.0  1.0
# 3    4    d       h          1.0  2.0

# %%
x=[{'a': i, 'b':5*i} for i in range(5)]
print(x)
pd.DataFrame(x)
# Out:
# [{'a': 0, 'b': 0}, {'a': 1, 'b': 5}, {'a': 2, 'b': 10}, {'a': 3, 'b': 15}, {'a': 4, 'b': 20}]
#    a   b
# 0  0   0
# 1  1   5
# 2  2  10
# 3  3  15
# 4  4  20

# %%
y=pd.DataFrame([{'a':1, 'b':2}, {'b':3, 'c':4}])
y=y.to_dict()
y
# Out:
# {'a': {0: 1.0, 1: nan}, 'b': {0: 2, 1: 3}, 'c': {0: nan, 1: 4.0}}

# %%
pd.DataFrame(np.random.randint(1,10),
columns=['a','b', 'c'],
index=[1,2,3,4])
# Out:
#    a  b  c
# 1  3  3  3
# 2  3  3  3
# 3  3  3  3
# 4  3  3  3

# %%
#index objects
x=pd.Index([1,2,3,4,5,2,3,4,1])
x
# Out:
# Int64Index([1, 2, 3, 4, 5, 2, 3, 4, 1], dtype='int64')

# %%
x[5]
# Out:
# 2

# %%
x[:]
# Out:
# Int64Index([1, 2, 3, 4, 5, 2, 3, 4, 1], dtype='int64')

# %%
x[2:5]
# Out:
# Int64Index([3, 4, 5], dtype='int64')

# %%
print(x.shape, x.size, x.ndim, x.dtype)
# Out:
# (9,) 9 1 int64

# %%
#ufuncs
x=np.random.RandomState(10)
y=pd.Series(x.randint(0,5,2))
y
# Out:
# 0    1
# 1    4
# dtype: int64

# %%
z=pd.DataFrame(x.randint(0,5,(2,4)), columns=['a', 'b', 'c', 'd'])
z
# Out:
#    a  b  c  d
# 0  0  2  0  4
# 1  3  0  4  3

# %%
np.exp(y)
# Out:
# 0     2.718282
# 1    54.598150
# dtype: float64

# %%
np.sin(z*np.pi/4)
# Out:
#           a    b             c             d
# 0  0.000000  1.0  0.000000e+00  1.224647e-16
# 1  0.707107  0.0  1.224647e-16  7.071068e-01

# %%
#universal functions
x=pd.Series({'a':1,'b':2, 'c':3, 'd':4}, name='x')
y=pd.Series({'e':5,'a':6, 'g':7, 'b':8}, name='y')
print(x)
y
# Out:
# a    1
# b    2
# c    3
# d    4
# Name: x, dtype: int64
# e    5
# a    6
# g    7
# b    8
# Name: y, dtype: int64

# %%
y/x
# Out:
# a    6.0
# b    4.0
# c    NaN
# d    NaN
# e    NaN
# g    NaN
# dtype: float64

# %%
x.index|y.index
# Out:
# <ipython-input-54-4dbfc85dc7ec>:1: FutureWarning: Index.__or__ operating as a set operation is deprecated, in the future this will be a logical operation matching Series.__or__.  Use index.union(other) instead.
#   x.index|y.index
# Index(['a', 'b', 'c', 'd', 'e', 'g'], dtype='object')

# %%
x=pd.Series([1,2,3], index=[4,5,6])
y=pd.Series([7,8,9], index=[6,5,3])
print(x)
print(y)
y
x+y
# Out:
# 4    1
# 5    2
# 6    3
# dtype: int64
# 6    7
# 5    8
# 3    9
# dtype: int64
# 3     NaN
# 4     NaN
# 5    10.0
# 6    10.0
# dtype: float64

# %%
x.add(y, fill_value=0)
# Out:
# 3     9.0
# 4     1.0
# 5    10.0
# 6    10.0
# dtype: float64

# %%
x
# Out:
#   name surname  age
# 0    a       e    1
# 1    b       f    2
# 2    c       g    3
# 3    d       h    4

# %%
y
# Out:
#    age name surname
# 0    1    a       e
# 1    2    b       f
# 2    3    c       g
# 3    4    d       h

# %%
x.merge(y)
# Out:
#   name surname  age
# 0    a       e    1
# 1    b       f    2
# 2    c       g    3
# 3    d       h    4
